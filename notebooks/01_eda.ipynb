# %%
# Insurance ML Project - EDA
# Objective: understand data and prepare for modeling

## Objetivo
# Prever probabilidade de sinistro em seguros auto

## Target
# coluna: sinistro (0 ou 1)

## Impacto de negócio
#- reduzir prejuízo
#- ajustar precificação

# %%
import pandas as pd

df = pd.read_csv("seguro_auto_historico.csv")
df.head()
# Out:
#    id_cliente  ano_contratacao  mes_contratacao     canal_venda  idade sexo  \
# 0      100000             2024               12  banco_parceiro     50    F
# 1      100001             2023               12        telefone     72    F
# 2      100002             2025               12             app     24    M
# 3      100003             2024               12             app     38    F
# 4      100004             2020               11        telefone     61    M
#
#   estado_civil  qtde_filhos estado    regiao  ... valor_segurado  \
# 0       casado            1     SP   Sudeste  ...       67885.85
# 1       casado            2     AL  Nordeste  ...       72394.33
# 2     solteiro            0     SC       Sul  ...       28890.12
# 3     solteiro            3     BA  Nordeste  ...      280723.40
# 4   divorciado            2     PR       Sul  ...       63105.55
#
#   premio_seguro  franquia  tipo_cobertura  assistencia_24h  carro_reserva  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 62 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id_cliente                      100000 non-null  int64
#  1   ano_contratacao                 100000 non-null  int64
#  2   mes_contratacao                 100000 non-null  int64
#  3   canal_venda                     100000 non-null  object
#  4   idade                           100000 non-null  int64
#  5   sexo                            100000 non-null  object
#  6   estado_civil                    100000 non-null  object
#  7   qtde_filhos                     100000 non-null  int64
#  8   estado                          100000 non-null  object
#  9   regiao                          100000 non-null  object
#  10  cidade_porte                    100000 non-null  object
#  11  profissao_grupo                 100000 non-null  object
# ...

# %%
df.describe()
# Out:
#           id_cliente  ano_contratacao  mes_contratacao          idade  \
# count  100000.000000     100000.00000     100000.00000  100000.000000
# mean   149999.500000       2022.85476          6.48982      40.927260
# std     28867.657797          1.58094          3.44815      12.938238
# min    100000.000000       2020.00000          1.00000      12.000000
# 25%    124999.750000       2022.00000          3.00000      31.000000
# 50%    149999.500000       2023.00000          6.00000      41.000000
# 75%    174999.250000       2024.00000          9.00000      50.000000
# max    199999.000000       2025.00000         12.00000     120.000000
#
#          qtde_filhos  renda_mensal_estimada  score_credito  \
# count  100000.000000           92075.000000   93991.000000
# mean        1.084530            7776.168519     853.557032
# std         1.114952            6554.247355     105.917952
# min        -3.000000          -43989.720000     -50.000000
# ...
